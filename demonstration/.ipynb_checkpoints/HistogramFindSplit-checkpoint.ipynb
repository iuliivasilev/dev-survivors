# %%
import pandas as pd
import numpy as np
import os
import time
import copy
import pathlib, tempfile

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from graphviz import Digraph
from joblib import Parallel, delayed
from scipy import stats

from survivors import metrics as metr
from survivors import constants as cnt
from survivors import criteria as crit
from numba import njit, jit, int32, float64
from lifelines import KaplanMeierFitter, NelsonAalenFitter

import cProfile
import pstats

# %load_ext line_profiler
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
@njit('f8(f8[:], f8[:], i8[:], i8[:], i8)', cache=True)
def lr_statistic(dur_1, dur_2, cens_1, cens_2, weightings):
    times = np.unique(np.hstack((dur_1, dur_2)))
    dur_1 = np.searchsorted(times, dur_1) + 1
    dur_2 = np.searchsorted(times, dur_2) + 1
    times_range = np.array([1, times.shape[0]], dtype=np.int32)

    bins = times_range[1] - times_range[0] + 1
    n_1_j = np.histogram(dur_1, bins=bins, range=times_range)[0]
    n_2_j = np.histogram(dur_2, bins=bins, range=times_range)[0]
    O_1_j = np.histogram(dur_1 * cens_1, bins=bins, range=times_range)[0]
    O_2_j = np.histogram(dur_2 * cens_2, bins=bins, range=times_range)[0]

    N_1_j = np.cumsum(n_1_j[::-1])[::-1]
    N_2_j = np.cumsum(n_2_j[::-1])[::-1]
    ind = np.where(N_1_j * N_2_j != 0)
    N_1_j = N_1_j[ind]
    N_2_j = N_2_j[ind]
    O_1_j = O_1_j[ind]
    O_2_j = O_2_j[ind]

    N_j = N_1_j + N_2_j
    O_j = O_1_j + O_2_j
    E_1_j = N_1_j * O_j / N_j
    res = np.zeros((N_j.shape[0], 3), dtype=np.float32)
    res[:, 1] = O_1_j - E_1_j
    res[:, 2] = E_1_j * (N_j - O_j) * N_2_j / (N_j * (N_j - 1))
    res[:, 0] = 1.0
    # if np.any(N_j <= 1):
    #     return 0.0
    if weightings == 2:
        res[:, 0] = N_j
    elif weightings == 3:
        res[:, 0] = np.sqrt(N_j)
    elif weightings == 4:
        res[:, 0] = np.cumprod((1.0 - O_j / (N_j + 1)))
    logrank = np.power((res[:, 0] * res[:, 1]).sum(), 2) / ((res[:, 0] * res[:, 0] * res[:, 2]).sum())
    return logrank


def weight_lr_fast(dur_A, dur_B, cens_A=None, cens_B=None, weightings=""):
    try:
        if cens_A is None:
            cens_A = np.ones(dur_A.shape[0])
        if cens_B is None:
            cens_B = np.ones(dur_B.shape[0])
        d = {"logrank": 1, "wilcoxon": 2, "tarone-ware": 3, "peto": 4}
        weightings = d.get(weightings, 1)
        logrank = lr_statistic(dur_A.astype("float64"),
                               dur_B.astype("float64"),
                               cens_A.astype("int64"),
                               cens_B.astype("int64"),
                               np.int64(weightings))
        return logrank
    except Exception as err:
        return 0.0
    
def logrank(durations_A, durations_B, event_observed_A=None, event_observed_B=None):
    return weight_lr_fast(durations_A, durations_B, event_observed_A, event_observed_B)

# %%
def optimal_criter_split(arr_nan, left, right, criterion):
    none_to = 0
    max_stat_val = 1.0
    if arr_nan.shape[1] > 0:
        left_and_nan = np.hstack([left, arr_nan])
        right_and_nan = np.hstack([right, arr_nan])
        a = criterion(left_and_nan[1], right[1], left_and_nan[0], right[0])
        b = criterion(left[1], right_and_nan[1], left[0], right_and_nan[0])
        # Nans move to a leaf with maximal statistical value
        none_to = int(a < b)
        max_stat_val = max(a, b)
#         print(a, b)
    else:
        max_stat_val = criterion(left[1], right[1], left[0], right[0])
    return (max_stat_val, none_to)


def get_attrs(max_stat_val, values, none_to, l_sh, r_sh, nan_sh):
    attrs = dict()
    attrs["stat_val"] = max_stat_val
    attrs["values"] = values
    if none_to:
        attrs["pos_nan"] = [0, 1]
        attrs["min_split"] = min(l_sh, r_sh+nan_sh)
    else:
        attrs["pos_nan"] = [1, 0]
        attrs["min_split"] = min(l_sh+nan_sh, r_sh)
    return attrs


def get_cont_attrs(uniq_set, arr_notnan, arr_nan, min_samples_leaf, criterion, 
                   signif_val, thres_cont_bin_max):
    if uniq_set.shape[0] > thres_cont_bin_max:
        uniq_set = np.quantile(arr_notnan[0], [i/float(thres_cont_bin_max) for i in range(1, thres_cont_bin_max)])
    else:  # Set intermediate points
        uniq_set = (uniq_set[:-1] + uniq_set[1:])*0.5
    uniq_set = list(set(np.round(uniq_set, 3)))
    attr_dicts = []
    for value in uniq_set:
        # Filter by attr value
        ind = arr_notnan[0] >= value
        left = arr_notnan[1:, np.where(ind)[0]]  #.astype(np.int32)  # inaccuracy in stat values
        right = arr_notnan[1:, np.where(~ind)[0]]  # .astype(np.int32)
        
        if min(left.shape[1], right.shape[1]) <= min_samples_leaf:
            continue
        max_stat_val, none_to = optimal_criter_split(arr_nan, left, right, criterion)
        if max_stat_val >= signif_val:
            attr_loc = get_attrs(max_stat_val, value, none_to,
                                 left.shape[1], right.shape[1], arr_nan.shape[1])
            attr_dicts.append(attr_loc)
    return attr_dicts


def get_categ_attrs(uniq_set, arr_notnan, arr_nan, min_samples_leaf, criterion, signif_val):
    attr_dicts = []
    pairs_uniq = power_set_nonover(uniq_set)
    for l, r in pairs_uniq:
        left = arr_notnan[1:, np.isin(arr_notnan[0], l)].astype(np.int32)
        right = arr_notnan[1:, np.isin(arr_notnan[0], r)].astype(np.int32)
        if min(left.shape[1], right.shape[1]) <= min_samples_leaf:
            continue
        max_stat_val, none_to = optimal_criter_split(arr_nan, left, right, criterion)
        if max_stat_val >= signif_val:
            attr_loc = get_attrs(max_stat_val, [list(l), list(r)], none_to,
                                 left.shape[1], right.shape[1], arr_nan.shape[1])
            attr_dicts.append(attr_loc)
    return attr_dicts


def best_attr_split(arr, criterion="logrank", type_attr="cont", thres_cont_bin_max=100,
                         signif=1.0, signif_stat=0.0, min_samples_leaf=10, bonf=True, verbose=0, **kwargs):
#     criterion = crit.CRITERIA_DICT.get(criterion, None)
    best_attr = {"stat_val": signif_stat, "p_value": signif,
                 "sign_split": 0, "values": [], "pos_nan": [1, 0]}
    if arr.shape[1] < 2*min_samples_leaf:
        return best_attr

    ind = np.isnan(arr[0])
    arr_nan = arr[1:, np.where(ind)[0]].astype(np.int32)
    arr_notnan = arr[:, np.where(~ind)[0]]
    
    if type_attr == "woe":
        arr_notnan[0], descr_np = transform_woe(arr_notnan[0], arr_notnan[1])
        
    
    uniq_set = np.unique(arr_notnan[0])
    
    if type_attr == "categ" and uniq_set.shape[0] > 0:
        attr_dicts = get_categ_attrs(uniq_set, arr_notnan, arr_nan,
                                     min_samples_leaf, logrank, signif_stat)
    else:
        attr_dicts = get_cont_attrs(uniq_set, arr_notnan, arr_nan,
                                    min_samples_leaf, logrank, signif_stat, thres_cont_bin_max)
    
    if len(attr_dicts) == 0:
        return best_attr
    best_attr = max(attr_dicts, key=lambda x: x["stat_val"])
    best_attr["p_value"] = stats.chi2.sf(best_attr["stat_val"], df=1)
    best_attr["sign_split"] = len(attr_dicts)
    if best_attr["sign_split"] > 0:
        if type_attr == "cont":
            best_attr["values"] = [f" >= {best_attr['values']}", f" < {best_attr['values']}"]
        elif type_attr == "categ":
            best_attr["values"] = [f" in {e}" for e in best_attr["values"]]
        elif type_attr == "woe":
            ind = descr_np[1] >= best_attr["values"]
            l, r = list(descr_np[0, np.where(ind)[0]]), list(descr_np[0, np.where(~ind)[0]])
            best_attr["values"] = [f" in {e}" for e in [l, r]]
        if bonf:
            best_attr["p_value"] *= best_attr["sign_split"]
        if verbose > 0:
            print(best_attr["p_value"], len(uniq_set))
    return best_attr

# %% [markdown]
# ### NEW SPLITTING

# %%
@njit('f8(i8[:], i8[:], i8[:], i8[:], i8)', cache=True)
def lr_hist_statistic(time_hist_1, time_hist_2, cens_hist_1, cens_hist_2, weightings):
    N_1_j = np.cumsum(time_hist_1[::-1])[::-1]
    N_2_j = np.cumsum(time_hist_2[::-1])[::-1]
    ind = np.where(N_1_j * N_2_j != 0)
    N_1_j = N_1_j[ind]
    N_2_j = N_2_j[ind]
    O_1_j = cens_hist_1[ind]
    O_2_j = cens_hist_2[ind]

    N_j = N_1_j + N_2_j
    O_j = O_1_j + O_2_j
    E_1_j = N_1_j * O_j / N_j
    res = np.zeros((N_j.shape[0], 3), dtype=np.float32)
    res[:, 1] = O_1_j - E_1_j
    res[:, 2] = E_1_j * (N_j - O_j) * N_2_j / (N_j * (N_j - 1))
    res[:, 0] = 1.0
    
    if weightings == 2:
        res[:, 0] = N_j
    elif weightings == 3:
        res[:, 0] = np.sqrt(N_j)
    elif weightings == 4:
        res[:, 0] = np.cumprod((1.0 - O_j / (N_j + 1)))
    stat_val = np.power((res[:, 0] * res[:, 1]).sum(), 2) / ((res[:, 0] * res[:, 0] * res[:, 2]).sum())
    return stat_val

def weight_hist_stat(time_hist_1, time_hist_2, cens_hist_1=None, cens_hist_2=None, weightings=""):
    try:
        if cens_hist_1 is None:
            cens_hist_1 = time_hist_1
        if cens_hist_2 is None:
            cens_hist_2 = time_hist_2
        d = {"logrank": 1, "wilcoxon": 2, "tarone-ware": 3, "peto": 4}
        weightings = d.get(weightings, 1)
        logrank = lr_hist_statistic(time_hist_1.astype("int64"),
                                    time_hist_2.astype("int64"),
                                    cens_hist_1.astype("int64"),
                                    cens_hist_2.astype("int64"),
                                    np.int64(weightings))
        return logrank
    except Exception as err:
        return 0.0
    
def logrank_hist(time_hist_1, time_hist_2, cens_hist_1=None, cens_hist_2=None):
    return weight_hist_stat(time_hist_1, time_hist_2, cens_hist_1, cens_hist_2)

def optimal_criter_split_hist(left_time_hist, left_cens_hist, 
                         right_time_hist, right_cens_hist,
                         na_time_hist, na_cens_hist, criterion):
    none_to = 0
    max_stat_val = 1.0
    if na_time_hist.shape[0] > 0:
        a = criterion(left_time_hist + na_time_hist, right_time_hist, 
                      left_cens_hist + na_cens_hist, right_cens_hist)
        b = criterion(left_time_hist, right_time_hist + na_time_hist, 
                      left_cens_hist, right_cens_hist + na_cens_hist)
        # Nans move to a leaf with maximal statistical value
        none_to = int(a < b)
        max_stat_val = max(a, b)
#         print(a, b)
    else:
        max_stat_val = criterion(left_time_hist, right_time_hist, 
                                 left_cens_hist, right_cens_hist)
    return (max_stat_val, none_to)

def split_time_to_bins(time):
    return np.searchsorted(np.unique(time), time)


def get_attrs(max_stat_val, values, none_to, l_sh, r_sh, nan_sh):
    attrs = dict()
    attrs["stat_val"] = max_stat_val
    attrs["values"] = values
    if none_to:
        attrs["pos_nan"] = [0, 1]
        attrs["min_split"] = min(l_sh, r_sh+nan_sh)
    else:
        attrs["pos_nan"] = [1, 0]
        attrs["min_split"] = min(l_sh+nan_sh, r_sh)
    return attrs

# %%
def hist_best_attr_split(arr, criterion="logrank", type_attr="cont", thres_cont_bin_max=100,
                         signif=1.0, signif_stat=0.0, min_samples_leaf=10, bonf=True, verbose=0, **kwargs):
    criterion = crit.CRITERIA_DICT.get(criterion, None)
    best_attr = {"stat_val": signif_stat, "p_value": signif,
                 "sign_split": 0, "values": [], "pos_nan": [1, 0]}
    if arr.shape[1] < 2*min_samples_leaf:
        return best_attr
    vals = arr[0]
    cens = arr[1]
    dur = arr[2]
    
    dur = split_time_to_bins(dur)
    time_bins = np.unique(dur)
    ind = np.isnan(vals)

    # split nan and not-nan
    dur_notna = dur[~ind]
    cens_notna = cens[~ind]
    vals_notna = vals[~ind]

    # find splitting values
    uniq_set = np.unique(vals_notna)
    if uniq_set.shape[0] > thres_cont_bin_max:
        uniq_set = np.quantile(vals_notna, [i/float(thres_cont_bin_max) for i in range(1, thres_cont_bin_max)])
    else:
        uniq_set = (uniq_set[:-1] + uniq_set[1:])*0.5
    uniq_set = np.unique(np.round(uniq_set, 3))
    index_vals_bin = np.digitize(vals_notna, uniq_set)

    # find global hist by times
    na_time_hist = np.bincount(dur[ind])
    na_cens_hist = np.bincount(dur[ind], weights=cens[ind])

    right_time_hist = np.bincount(dur_notna)
    right_cens_hist = np.bincount(dur_notna, weights=cens_notna)
    left_time_hist = np.zeros_like(right_cens_hist, dtype=np.int32)
    left_cens_hist = left_time_hist.copy()
    
    num_nan = ind.sum()
    num_r = dur_notna.shape[0]
    num_l = 0

    # for each split values get branches
    attr_dicts = []
    for u in np.unique(index_vals_bin)[:-1]:
        curr_mask = index_vals_bin == u
        curr_n = curr_mask.sum()
        curr_time_hist = np.bincount(dur_notna, weights=curr_mask).astype("int32")
        curr_cens_hist = np.bincount(dur_notna, weights=cens_notna*curr_mask).astype("int32")
        left_time_hist += curr_time_hist
        left_cens_hist += curr_cens_hist
        right_time_hist -= curr_time_hist
        right_cens_hist -= curr_cens_hist
        num_l += curr_n
        num_r -= curr_n
        
        if min(num_l, num_r) <= min_samples_leaf:
            continue
        max_stat_val, none_to = optimal_criter_split_hist(left_time_hist, left_cens_hist, 
                                                     right_time_hist, right_cens_hist,
                                                     na_time_hist, na_cens_hist, logrank_hist)
        
        if max_stat_val >= signif_stat:
            attr_loc = get_attrs(max_stat_val, uniq_set[u], none_to, num_l, num_r, num_nan)
            attr_dicts.append(attr_loc)
#         print(uniq_set[u], max_stat_val)
    
    if len(attr_dicts) == 0:
        return best_attr
    best_attr = max(attr_dicts, key=lambda x: x["stat_val"])
    best_attr["p_value"] = stats.chi2.sf(best_attr["stat_val"], df=1)
    best_attr["sign_split"] = len(attr_dicts)
    if best_attr["sign_split"] > 0:
        if type_attr == "cont":
            best_attr["values"] = [f" <= {best_attr['values']}", f" > {best_attr['values']}"]
        elif type_attr == "categ":
            best_attr["values"] = [f" in {e}" for e in best_attr["values"]]
        elif type_attr == "woe":
            ind = descr_np[1] >= best_attr["values"]
            l, r = list(descr_np[0, np.where(ind)[0]]), list(descr_np[0, np.where(~ind)[0]])
            best_attr["values"] = [f" in {e}" for e in [l, r]]
        if bonf:
            best_attr["p_value"] *= best_attr["sign_split"]
        if verbose > 0:
            print(best_attr["p_value"], len(uniq_set))
    return best_attr

# %%
# def hists_(dur, cens, ):    
#     # split nan and not-nan
#     dur_notna = np.append(dur[~nan_ind], time_bins)
#     cens_notna = np.append(cens[~nan_ind], np.zeros(time_bins.shape[0]))

#     # find global hist by times
#     na_time_hist = np.bincount(dur_na) - 1
#     na_cens_hist = np.bincount(dur_na, weights=cens_na)
    
#     return 

def half_miss_hist_best_attr_split(arr, criterion="logrank", type_attr="cont", thres_cont_bin_max=100,
                         signif=1.0, signif_stat=0.0, min_samples_leaf=10, bonf=True, verbose=0, **kwargs):
    criterion = crit.CRITERIA_DICT.get(criterion, None)
    best_attr = {"stat_val": signif_stat, "p_value": signif,
                 "sign_split": 0, "values": [], "pos_nan": [1, 0]}
    if arr.shape[1] < 2*min_samples_leaf:
        return best_attr
    vals = arr[0]
    cens = arr[1]
    dur = arr[2]
    
    dur = split_time_to_bins(dur)
    ind = np.isnan(vals)
    vals_notna = vals[~ind]

    # find splitting values
    uniq_set = np.unique(vals_notna)
    if uniq_set.shape[0] > thres_cont_bin_max:
        uniq_set = np.quantile(vals_notna, [i/float(thres_cont_bin_max) for i in range(1, thres_cont_bin_max)])
    else:
        uniq_set = (uniq_set[:-1] + uniq_set[1:])*0.5
    uniq_set = np.unique(np.round(uniq_set, 3))
    
    index_vals_bin = np.append(np.digitize(vals_notna, uniq_set), -1)
    
    # split nan and not-nan
    dur_notna = np.append(dur[~ind], dur.max())
    cens_notna = np.append(cens[~ind], 0.0)
    
    dur_na = np.append(dur[ind], dur.max())
    cens_na = np.append(cens[ind], 0.0)

    # find global hist by times
    na_time_hist = np.bincount(dur_na)
    na_time_hist[-1] -= 1
    na_cens_hist = np.bincount(dur_na, weights=cens_na)

    right_time_hist = np.bincount(dur_notna)
    right_time_hist[-1] -= 1
    right_cens_hist = np.bincount(dur_notna, weights=cens_notna)
    left_time_hist = np.zeros_like(right_time_hist, dtype=np.int32)
    left_cens_hist = left_time_hist.copy()
    
    num_nan = ind.sum()
    num_r = dur_notna.shape[0] - 1
    num_l = 0

    # for each split values get branches
    attr_dicts = []
    for u in np.unique(index_vals_bin)[1:-1]:
        curr_mask = index_vals_bin == u
        curr_n = curr_mask.sum()
        curr_time_hist = np.bincount(dur_notna, weights=curr_mask).astype("int32")
        curr_cens_hist = np.bincount(dur_notna, weights=cens_notna*curr_mask).astype("int32")
        left_time_hist += curr_time_hist
        left_cens_hist += curr_cens_hist
        right_time_hist -= curr_time_hist
        right_cens_hist -= curr_cens_hist
        num_l += curr_n
        num_r -= curr_n
        
        if min(num_l, num_r) <= min_samples_leaf:
            continue
        max_stat_val, none_to = optimal_criter_split_hist(left_time_hist, left_cens_hist, 
                                                     right_time_hist, right_cens_hist,
                                                     na_time_hist, na_cens_hist, logrank_hist)
        
        if max_stat_val >= signif_stat:
            attr_loc = get_attrs(max_stat_val, uniq_set[u], none_to, num_l, num_r, num_nan)
            attr_dicts.append(attr_loc)
#         print(uniq_set[u], max_stat_val)
    
    if len(attr_dicts) == 0:
        return best_attr
    best_attr = max(attr_dicts, key=lambda x: x["stat_val"])
    best_attr["p_value"] = stats.chi2.sf(best_attr["stat_val"], df=1)
    best_attr["sign_split"] = len(attr_dicts)
    if best_attr["sign_split"] > 0:
        if type_attr == "cont":
            best_attr["values"] = [f" <= {best_attr['values']}", f" > {best_attr['values']}"]
        elif type_attr == "categ":
            best_attr["values"] = [f" in {e}" for e in best_attr["values"]]
        elif type_attr == "woe":
            ind = descr_np[1] >= best_attr["values"]
            l, r = list(descr_np[0, np.where(ind)[0]]), list(descr_np[0, np.where(~ind)[0]])
            best_attr["values"] = [f" in {e}" for e in [l, r]]
        if bonf:
            best_attr["p_value"] *= best_attr["sign_split"]
        if verbose > 0:
            print(best_attr["p_value"], len(uniq_set))
    return best_attr

# %%
def miss_hist_best_attr_split(arr, criterion="logrank", type_attr="cont", thres_cont_bin_max=100,
                         signif=1.0, signif_stat=0.0, min_samples_leaf=10, bonf=True, verbose=0, **kwargs):
    criterion = crit.CRITERIA_DICT.get(criterion, None)
    best_attr = {"stat_val": signif_stat, "p_value": signif,
                 "sign_split": 0, "values": [], "pos_nan": [1, 0]}
    if arr.shape[1] < 2*min_samples_leaf:
        return best_attr
    vals = arr[0]
    cens = arr[1]
    dur = arr[2]
    
    dur = split_time_to_bins(dur)
    time_bins = np.unique(dur)
#     print(time_bins)
    
    bins = dur
    ind = np.isnan(vals)

    # split nan and not-nan
    dur_notna = dur[~ind]
    cens_notna = cens[~ind]
    vals_notna = vals[~ind]

    # find splitting values
    uniq_set = np.unique(vals_notna)
    if uniq_set.shape[0] > thres_cont_bin_max:
        uniq_set = np.quantile(vals_notna, [i/float(thres_cont_bin_max) for i in range(1, thres_cont_bin_max)])
    else:
        uniq_set = (uniq_set[:-1] + uniq_set[1:])*0.5
    uniq_set = np.unique(np.round(uniq_set, 3))
    index_vals_bin = np.digitize(vals_notna, uniq_set)

    # find global hist by times
    na_time_hist = np.histogram(dur[ind], bins = time_bins)[0]
    na_cens_hist = np.histogram(dur[ind], bins = time_bins, weights = cens[ind])[0].astype("int32")

    right_time_hist = np.histogram(dur_notna, bins = time_bins)[0]
    right_cens_hist = np.histogram(dur_notna, bins = time_bins, weights = cens_notna)[0].astype("int32")
    left_time_hist = np.zeros_like(right_time_hist, dtype = np.int32)
    left_cens_hist = left_time_hist.copy()
    
    num_nan = ind.sum()
    num_r = dur_notna.shape[0]
    num_l = 0

    # for each split values get branches
    attr_dicts = []
    for u in np.unique(index_vals_bin)[:-1]:
        curr_mask = index_vals_bin == u
        curr_n = curr_mask.sum()
        curr_time_hist = np.histogram(dur_notna[curr_mask], bins = time_bins)[0]
        curr_cens_hist = np.histogram(dur_notna[curr_mask], bins = time_bins, weights=cens_notna[curr_mask])[0].astype("int32")
        left_time_hist += curr_time_hist
        left_cens_hist += curr_cens_hist
        right_time_hist -= curr_time_hist
        right_cens_hist -= curr_cens_hist
        num_l += curr_n
        num_r -= curr_n
        
        if min(num_l, num_r) <= min_samples_leaf:
            continue
        max_stat_val, none_to = optimal_criter_split_hist(left_time_hist, left_cens_hist, 
                                                     right_time_hist, right_cens_hist,
                                                     na_time_hist, na_cens_hist, logrank_hist)
        
        if max_stat_val >= signif_stat:
            attr_loc = get_attrs(max_stat_val, uniq_set[u], none_to, num_l, num_r, num_nan)
            attr_dicts.append(attr_loc)
#         print(uniq_set[u], max_stat_val)
    
    if len(attr_dicts) == 0:
        return best_attr
    best_attr = max(attr_dicts, key=lambda x: x["stat_val"])
    best_attr["p_value"] = stats.chi2.sf(best_attr["stat_val"], df=1)
    best_attr["sign_split"] = len(attr_dicts)
    if best_attr["sign_split"] > 0:
        if type_attr == "cont":
            best_attr["values"] = [f" >= {best_attr['values']}", f" < {best_attr['values']}"]
        elif type_attr == "categ":
            best_attr["values"] = [f" in {e}" for e in best_attr["values"]]
        elif type_attr == "woe":
            ind = descr_np[1] >= best_attr["values"]
            l, r = list(descr_np[0, np.where(ind)[0]]), list(descr_np[0, np.where(~ind)[0]])
            best_attr["values"] = [f" in {e}" for e in [l, r]]
        if bonf:
            best_attr["p_value"] *= best_attr["sign_split"]
        if verbose > 0:
            print(best_attr["p_value"], len(uniq_set))
    return best_attr

# %% [markdown]
# ### Тестирование

# %%
dur = np.random.uniform(0, 10000, 10000)
cens = np.random.choice(2, 10000)
vals = np.random.uniform(100, 8000, 10000)

arr = np.vstack([vals, cens, dur])

# %%
hist_best_attr_split(arr)
# Out:
# 182.493 5.6360321044921875
# 271.021 2.5912275314331055
# 347.896 2.0125250816345215
# 415.59 0.21973085403442383
# 492.347 1.6572258472442627
# 574.023 1.9961357116699219
# 665.152 1.3391757011413574
# 744.072 0.6490407586097717
# 806.195 0.642905592918396
# 879.519 1.361128330230713
# 968.252 0.8618687391281128
# 1052.857 1.8673123121261597
# 1131.694 0.7261466979980469
# 1197.958 1.6209357976913452
# 1276.037 1.6727993488311768
# 1353.387 1.5697966814041138
# 1432.374 0.6530634760856628
# 1516.655 1.1923967599868774
# 1601.508 0.7626166343688965
# 1697.198 0.3329196274280548
# 1772.567 0.254820853471756
# 1855.971 0.23110482096672058
# 1933.206 0.075136698782444
# 2024.433 0.02039954625070095
# 2103.029 0.0016825671773403883
# 2179.196 0.035860273987054825
# 2264.373 0.08952926099300385
# 2340.105 0.038424842059612274
# 2417.926 0.02317448891699314
# 2507.87 0.15453454852104187
# 2582.578 0.35974159836769104
# 2661.775 0.6719045042991638
# 2745.47 0.5109747052192688
# 2828.959 0.8455283641815186
# 2909.512 0.9068726301193237
# 2977.661 1.460143804550171
# 3049.048 1.3276406526565552
# 3129.093 0.9470075368881226
# 3218.867 1.3330847024917603
# 3312.191 0.8660010695457458
# 3391.216 0.8734785914421082
# 3469.742 0.1628037989139557
# 3554.204 0.003952044993638992
# 3626.202 0.0021404437720775604
# 3701.03 0.006249685306102037
# 3768.257 0.03354731202125549
# 3851.79 0.10167208313941956
# 3919.918 0.002824697643518448
# 3974.797 0.025034911930561066
# 4050.471 0.29828086495399475
# 4129.304 0.3161373436450958
# 4202.167 0.27410754561424255
# 4274.644 0.3127235770225525
# 4363.02 0.013948761858046055
# 4442.528 0.011038919910788536
# 4524.949 0.011172758415341377
# 4599.291 0.03984823450446129
# 4698.086 0.18451924622058868
# 4777.199 0.14930538833141327
# 4861.007 0.0796930193901062
# 4932.555 0.17069964110851288
# 5006.664 0.2783004343509674
# 5084.297 0.08570548892021179
# 5168.288 0.18794399499893188
# 5262.437 0.14148476719856262
# 5342.203 0.09863760322332382
# 5428.913 0.39215967059135437
# 5510.383 0.05263476073741913
# 5587.845 0.01058012805879116
# 5672.95 0.1211739182472229
# 5742.987 0.37598171830177307
# 5824.125 1.171750783920288
# 5899.781 0.8006278872489929
# 5993.588 0.9515009522438049
# 6077.578 1.2698900699615479
# 6165.648 1.9627529382705688
# 6235.792 1.314313530921936
# 6321.982 1.2844263315200806
# 6390.06 1.9536689519882202
# 6457.184 0.7673499584197998
# 6532.504 0.5563810467720032
# 6616.319 0.7454858422279358
# 6694.163 0.6554995179176331
# 6773.664 0.4451330602169037
# 6849.181 0.392328143119812
# 6934.809 0.17909659445285797
# 7005.078 0.000586838461458683
# 7075.181 0.02138865366578102
# 7138.572 0.025900766253471375
# 7221.452 0.17458900809288025
# 7293.288 0.16347035765647888
# 7359.864 0.06302173435688019
# 7446.999 0.003349639941006899
# 7525.588 0.4981361925601959
# 7595.363 0.30177563428878784
# 7667.063 0.0023157780524343252
# 7761.525 0.029517993330955505
# 7834.666 0.00866900384426117
# 7923.788 0.04512036591768265
# {'stat_val': 5.6360321044921875,
#  'values': [' >= 182.493', ' < 182.493'],
#  'pos_nan': [1, 0],
#  'min_split': 100,
#  'p_value': 1.741903386448486,
#  'sign_split': 99}

# %%
# %timeit best_attr_split(arr)
# Out:
# 145 ms ± 852 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit hist_best_attr_split(arr)
# Out:
# 28.3 ms ± 345 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
profiler = cProfile.Profile()
profiler.enable()
hist_best_attr_split(arr)
profiler.disable()
stats_ = pstats.Stats(profiler).sort_stats('cumtime')
stats_.print_stats()
stats_.dump_stats('hist_output.pstats')
# Out:
#          3230 function calls (3218 primitive calls) in 0.034 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.033    0.017 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\IPython\core\interactiveshell.py:3362(run_code)
#         2    0.000    0.000    0.033    0.017 {built-in method builtins.exec}
#         1    0.000    0.000    0.033    0.033 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\2418375740.py:1(<cell line: 3>)
#         1    0.006    0.006    0.033    0.033 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3382176909.py:1(hist_best_attr_split)
#        99    0.000    0.000    0.016    0.000 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3474870837.py:48(optimal_criter_split_hist)
#        99    0.000    0.000    0.016    0.000 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3474870837.py:45(logrank_hist)
#        99    0.001    0.000    0.016    0.000 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3474870837.py:28(weight_hist_stat)
#        99    0.014    0.000    0.014    0.000 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3474870837.py:1(lr_hist_statistic)
#   231/219    0.004    0.000    0.007    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       202    0.000    0.000    0.004    0.000 <__array_function__ internals>:177(bincount)
#       596    0.003    0.000    0.003    0.000 {method 'astype' of 'numpy.ndarray' objects}
#       200    0.000    0.000    0.002    0.000 {method 'sum' of 'numpy.ndarray' objects}
#       200    0.000    0.000    0.002    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_methods.py:46(_sum)
#       208    0.002    0.000    0.002    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         5    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(unique)
#         1    0.000    0.000    0.001    0.001 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3474870837.py:66(split_time_to_bins)
#         5    0.000    0.000    0.001    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\arraysetops.py:138(unique)
#         5    0.000    0.000    0.001    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\arraysetops.py:320(_unique1d)
#         6    0.000    0.000    0.001    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:51(_wrapfunc)
#         2    0.000    0.000    0.001    0.001 <__array_function__ internals>:177(searchsorted)
#         2    0.000    0.000    0.001    0.001 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:1319(searchsorted)
#         2    0.001    0.001    0.001    0.001 {method 'searchsorted' of 'numpy.ndarray' objects}
#         5    0.001    0.000    0.001    0.000 {method 'sort' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.001    0.001 <__array_function__ internals>:177(quantile)
#         1    0.000    0.000    0.001    0.001 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4143(quantile)
#         1    0.000    0.000    0.001    0.001 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4375(_quantile_unchecked)
#         1    0.000    0.000    0.001    0.001 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:3651(_ureduce)
#         1    0.000    0.000    0.001    0.001 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4527(_quantile_ureduce_func)
#         1    0.000    0.000    0.001    0.001 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4595(_quantile)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(digitize)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:5399(digitize)
#         1    0.000    0.000    0.000    0.000 {method 'partition' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_distn_infrastructure.py:2044(sf)
#        99    0.000    0.000    0.000    0.000 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3474870837.py:70(get_attrs)
#         6    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_distn_infrastructure.py:529(argsreduce)
#       198    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(broadcast_arrays)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:479(broadcast_arrays)
#         5    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:69(_wrapreduction)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\codeop.py:117(__call__)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4396(_quantile_is_valid)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(all)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:545(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4560(_get_indexes)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:339(_broadcast_to)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(any)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:2404(all)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_distn_infrastructure.py:998(_open_support_mask)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:2305(any)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:597(find_common_type)
#       202    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\multiarray.py:883(bincount)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(round_)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:573(_can_coerce_all)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:3764(round_)
#         4    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:356(issubdtype)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(around)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:3257(around)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(take)
#       101    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_methods.py:54(_any)
#       101    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(place)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\IPython\core\interactiveshell.py:3215(_update_code_co_name)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_ufunc_config.py:32(seterr)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(zeros_like)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4472(_lerp)
#         1    0.000    0.000    0.000    0.000 {method 'round' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3382176909.py:23(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_ufunc_config.py:429(__enter__)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numeric.py:76(zeros_like)
#         2    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.generic' objects}
#         8    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:282(issubclass_)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:93(take)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:1888(place)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         3    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(atleast_1d)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(concatenate)
#         5    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#        21    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_distn_infrastructure.py:959(_argcheck)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\shape_base.py:23(atleast_1d)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:415(_broadcast_shape)
#        99    0.000    0.000    0.000    0.000 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3382176909.py:68(<lambda>)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\contextlib.py:279(helper)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_continuous_distns.py:1315(_sf)
#         5    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\arraysetops.py:125(_unpack_tuple)
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         3    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(shape)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4450(_get_gamma)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_ufunc_config.py:434(__exit__)
#         4    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\dis.py:453(findlinestarts)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_ufunc_config.py:131(geterr)
#         1    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.generic' objects}
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\contextlib.py:130(__enter__)
#        13    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:110(<lambda>)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\contextlib.py:139(__exit__)
#         3    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        14    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:582(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(empty_like)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\contextlib.py:102(__init__)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:537(<listcomp>)
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath._insert}
#         5    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:70(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\traitlets\traitlets.py:675(__get__)
#         4    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\IPython\core\compilerop.py:174(extra_flags)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(copyto)
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#        25    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_methods.py:60(_all)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         1    0.000    0.000    0.000    0.000 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\2418375740.py:1(<cell line: 4>)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:346(iterable)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\IPython\core\interactiveshell.py:3313(compare)
#         6    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'code' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         4    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:649(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_distn_infrastructure.py:573(<listcomp>)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_distn_infrastructure.py:971(_get_support)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\traitlets\traitlets.py:643(get)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\IPython\core\interactiveshell.py:1192(user_global_ns)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_ufunc_config.py:425(__init__)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:25(_maybe_view_as_subclass)
#         6    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:344(<genexpr>)
#         4    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:541(<genexpr>)
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         5    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:1965(shape)
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath._monotonicity}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:2399(_all_dispatcher)
#         5    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\arraysetops.py:133(_unique_dispatcher)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:1884(_place_dispatcher)
#         3    0.000    0.000    0.000    0.000 {method '__exit__' of 'numpy.nditer' objects}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:650(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numeric.py:72(_zeros_like_dispatcher)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:89(_take_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:1315(_searchsorted_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:1961(_shape_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:2300(_any_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:3253(_around_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:475(_broadcast_arrays_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:111(<lambda>)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4138(_quantile_dispatcher)
#         1    0.000    0.000    0.000    0.000 <string>:2(_parse_args)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\multiarray.py:148(concatenate)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\multiarray.py:80(empty_like)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\shape_base.py:19(_atleast_1d_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:5395(_digitize_dispatcher)
#         2    0.000    0.000    0.000    0.000 {method 'co_lines' of 'code' objects}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\multiarray.py:1071(copyto)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
profiler = cProfile.Profile()
profiler.enable()
best_attr_split(arr)
profiler.disable()
stats_ = pstats.Stats(profiler).sort_stats('cumtime')
stats_.print_stats()
stats_.dump_stats('old_output.pstats')
# Out:
#          2351 function calls (2342 primitive calls) in 0.152 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.152    0.076 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\IPython\core\interactiveshell.py:3362(run_code)
#         2    0.000    0.000    0.152    0.076 {built-in method builtins.exec}
#         1    0.000    0.000    0.152    0.152 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\327923047.py:1(<cell line: 3>)
#         1    0.001    0.001    0.152    0.152 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3775720439.py:70(best_attr_split)
#         1    0.012    0.012    0.148    0.148 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3775720439.py:30(get_cont_attrs)
#        99    0.000    0.000    0.131    0.001 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3775720439.py:1(optimal_criter_split)
#        99    0.000    0.000    0.131    0.001 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3314807869.py:58(logrank)
#        99    0.001    0.000    0.130    0.001 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3314807869.py:41(weight_lr_fast)
#        99    0.128    0.001    0.128    0.001 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3314807869.py:1(lr_statistic)
#   220/211    0.005    0.000    0.008    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       200    0.000    0.000    0.005    0.000 <__array_function__ internals>:177(where)
#         2    0.000    0.000    0.002    0.001 <__array_function__ internals>:177(unique)
#         2    0.000    0.000    0.002    0.001 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\arraysetops.py:138(unique)
#         2    0.000    0.000    0.002    0.001 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\arraysetops.py:320(_unique1d)
#         2    0.002    0.001    0.002    0.001 {method 'sort' of 'numpy.ndarray' objects}
#       399    0.001    0.000    0.001    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.001    0.001 <__array_function__ internals>:177(quantile)
#         1    0.000    0.000    0.001    0.001 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4143(quantile)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4375(_quantile_unchecked)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:3651(_ureduce)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4527(_quantile_ureduce_func)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4595(_quantile)
#         1    0.000    0.000    0.000    0.000 {method 'partition' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_distn_infrastructure.py:2044(sf)
#        99    0.000    0.000    0.000    0.000 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3474870837.py:70(get_attrs)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\codeop.py:117(__call__)
#       198    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_distn_infrastructure.py:529(argsreduce)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         3    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(broadcast_arrays)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:479(broadcast_arrays)
#         5    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:69(_wrapreduction)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\IPython\core\interactiveshell.py:3215(_update_code_co_name)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(all)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(any)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4396(_quantile_is_valid)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:545(<listcomp>)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:339(_broadcast_to)
#       200    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\multiarray.py:341(where)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:2404(all)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4560(_get_indexes)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:2305(any)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_distn_infrastructure.py:998(_open_support_mask)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         8    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:597(find_common_type)
#         4    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:51(_wrapfunc)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(round_)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:3764(round_)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:573(_can_coerce_all)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(around)
#       101    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:3257(around)
#         5    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_methods.py:54(_any)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(take)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(place)
#       100    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\contextlib.py:130(__enter__)
#         1    0.000    0.000    0.000    0.000 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3775720439.py:33(<listcomp>)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_ufunc_config.py:32(seterr)
#         2    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.generic' objects}
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\contextlib.py:279(helper)
#         1    0.000    0.000    0.000    0.000 {method 'round' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4472(_lerp)
#         4    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\dis.py:453(findlinestarts)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:356(issubdtype)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_ufunc_config.py:429(__enter__)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\contextlib.py:139(__exit__)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:93(take)
#        99    0.000    0.000    0.000    0.000 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3775720439.py:97(<lambda>)
#        15    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:1888(place)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(atleast_1d)
#         3    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\contextlib.py:102(__init__)
#         4    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\IPython\core\compilerop.py:174(extra_flags)
#         6    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:282(issubclass_)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_distn_infrastructure.py:959(_argcheck)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\traitlets\traitlets.py:675(__get__)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_continuous_distns.py:1315(_sf)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(concatenate)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\shape_base.py:23(atleast_1d)
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:415(_broadcast_shape)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(shape)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4450(_get_gamma)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_ufunc_config.py:434(__exit__)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:110(<lambda>)
#         1    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.generic' objects}
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_ufunc_config.py:131(geterr)
#         3    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\IPython\core\interactiveshell.py:3313(compare)
#         3    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath._insert}
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'code' objects}
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\traitlets\traitlets.py:643(get)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:537(<listcomp>)
#        14    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:582(<listcomp>)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         5    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:70(<dictcomp>)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:346(iterable)
#         1    0.000    0.000    0.000    0.000 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\327923047.py:1(<cell line: 4>)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_methods.py:60(_all)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\arraysetops.py:125(_unpack_tuple)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#        22    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_distn_infrastructure.py:971(_get_support)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:649(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\IPython\core\interactiveshell.py:1192(user_global_ns)
#         6    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_ufunc_config.py:425(__init__)
#         4    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:541(<genexpr>)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\arraysetops.py:133(_unique_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_distn_infrastructure.py:573(<listcomp>)
#         2    0.000    0.000    0.000    0.000 {method 'co_lines' of 'code' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:1965(shape)
#         6    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:344(<genexpr>)
#         4    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method '__exit__' of 'numpy.nditer' objects}
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:25(_maybe_view_as_subclass)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:1884(_place_dispatcher)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\multiarray.py:148(concatenate)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:2399(_all_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:111(<lambda>)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:89(_take_dispatcher)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         5    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:650(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:1961(_shape_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:2300(_any_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:3253(_around_dispatcher)
#         1    0.000    0.000    0.000    0.000 <string>:2(_parse_args)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:475(_broadcast_arrays_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4138(_quantile_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\shape_base.py:19(_atleast_1d_dispatcher)

# %% [markdown]
# ### COVID TEST

# %%
x = []
time_old = []
time_hist = []
time_hist_2 = []
res_old = []
res_hist = []
res_hist_2 = []
for i in range(100, 20000, 500):
    size_sample = i
    dur = np.random.uniform(0, 10000, size_sample)
    cens = np.random.choice(2, size_sample)
    vals = np.random.uniform(100, 8000, size_sample)
#     nan_index = np.random.uniform(0, 1, size_sample) < 0.25
#     vals[nan_index] = np.nan

    arr = np.vstack([vals, cens, dur])
    time_1 = time.time()
    res_old.append(best_attr_split(arr))
    time_2 = time.time()
    res_hist.append(half_miss_hist_best_attr_split(arr))
    time_3 = time.time()
    res_hist_2.append(hist_best_attr_split(arr))
    time_4 = time.time()
    
    x.append(size_sample)
    time_old.append(time_2 - time_1)
    time_hist.append(time_3 - time_2)
    time_hist_2.append(time_4 - time_3)
    
plt.plot(x, time_old)
plt.plot(x, time_hist)
plt.plot(x, time_hist_2)

# %%
res_hist_2
# Out:
# [{'stat_val': 1.9248254299163818,
#   'values': [' <= 6508.95', ' > 6508.95'],
#   'pos_nan': [1, 0],
#   'min_split': 22,
#   'p_value': 13.060728912897732,
#   'sign_split': 79},
#  {'stat_val': 4.240798473358154,
#   'values': [' <= 7730.186', ' > 7730.186'],
#   'pos_nan': [1, 0],
#   'min_split': 24,
#   'p_value': 3.827969474595702,
#   'sign_split': 97},
#  {'stat_val': 3.306309223175049,
#   'values': [' <= 7841.65', ' > 7841.65'],
#   'pos_nan': [1, 0],
#   'min_split': 22,
#   'p_value': 6.832418708801845,
#   'sign_split': 99},
#  {'stat_val': 9.291913032531738,
#   'values': [' <= 3560.759', ' > 3560.759'],
#   'pos_nan': [1, 0],
#   'min_split': 688,
#   'p_value': 0.22786599415610534,
#   'sign_split': 99},
#  {'stat_val': 4.049301624298096,
#   'values': [' <= 255.019', ' > 255.019'],
#   'pos_nan': [1, 0],
#   'min_split': 42,
#   'p_value': 4.374772631387701,
#   'sign_split': 99},
#  {'stat_val': 2.5701167583465576,
#   'values': [' <= 6839.233', ' > 6839.233'],
#   'pos_nan': [1, 0],
#   'min_split': 390,
#   'p_value': 10.78106969844296,
#   'sign_split': 99},
#  {'stat_val': 4.834317684173584,
#   'values': [' <= 7178.22', ' > 7178.22'],
#   'pos_nan': [1, 0],
#   'min_split': 310,
#   'p_value': 2.761969177805329,
#   'sign_split': 99},
#  {'stat_val': 6.199769973754883,
#   'values': [' <= 1485.414', ' > 1485.414'],
#   'pos_nan': [1, 0],
#   'min_split': 684,
#   'p_value': 1.2648924747316572,
#   'sign_split': 99},
#  {'stat_val': 4.891524791717529,
#   'values': [' <= 435.581', ' > 435.581'],
#   'pos_nan': [1, 0],
#   'min_split': 164,
#   'p_value': 2.671895172476448,
#   'sign_split': 99},
#  {'stat_val': 3.966035842895508,
#   'values': [' <= 1664.243', ' > 1664.243'],
#   'pos_nan': [1, 0],
#   'min_split': 920,
#   'p_value': 4.596267965447167,
#   'sign_split': 99},
#  {'stat_val': 3.124359369277954,
#   'values': [' <= 4333.113', ' > 4333.113'],
#   'pos_nan': [1, 0],
#   'min_split': 2397,
#   'p_value': 7.635888086376121,
#   'sign_split': 99},
#  {'stat_val': 9.97868824005127,
#   'values': [' <= 6030.012', ' > 6030.012'],
#   'pos_nan': [1, 0],
#   'min_split': 1344,
#   'p_value': 0.15677883836777895,
#   'sign_split': 99},
#  {'stat_val': 9.188007354736328,
#   'values': [' <= 5581.857', ' > 5581.857'],
#   'pos_nan': [1, 0],
#   'min_split': 1891,
#   'p_value': 0.24116988754082086,
#   'sign_split': 99},
#  {'stat_val': 6.763279438018799,
#   'values': [' <= 4161.476', ' > 4161.476'],
#   'pos_nan': [1, 0],
#   'min_split': 3234,
#   'p_value': 0.9212207062295539,
#   'sign_split': 99},
#  {'stat_val': 3.321990728378296,
#   'values': [' <= 7341.855', ' > 7341.855'],
#   'pos_nan': [1, 0],
#   'min_split': 568,
#   'p_value': 6.767541748676621,
#   'sign_split': 99},
#  {'stat_val': 7.546189308166504,
#   'values': [' <= 701.489', ' > 701.489'],
#   'pos_nan': [1, 0],
#   'min_split': 532,
#   'p_value': 0.5953574535709721,
#   'sign_split': 99},
#  {'stat_val': 5.039513111114502,
#   'values': [' <= 7925.371', ' > 7925.371'],
#   'pos_nan': [1, 0],
#   'min_split': 81,
#   'p_value': 2.4527697995489794,
#   'sign_split': 99},
#  {'stat_val': 4.7320756912231445,
#   'values': [' <= 4807.366', ' > 4807.366'],
#   'pos_nan': [1, 0],
#   'min_split': 3526,
#   'p_value': 2.9309084998434844,
#   'sign_split': 99},
#  {'stat_val': 4.346709251403809,
#   'values': [' <= 2336.364', ' > 2336.364'],
#   'pos_nan': [1, 0],
#   'min_split': 2548,
#   'p_value': 3.670972377589758,
#   'sign_split': 99},
#  {'stat_val': 2.7300808429718018,
#   'values': [' <= 7155.247', ' > 7155.247'],
#   'pos_nan': [1, 0],
#   'min_split': 1056,
#   'p_value': 9.748955709556341,
#   'sign_split': 99},
#  {'stat_val': 1.2770568132400513,
#   'values': [' <= 6506.997', ' > 6506.997'],
#   'pos_nan': [1, 0],
#   'min_split': 1919,
#   'p_value': 25.5862519213238,
#   'sign_split': 99},
#  {'stat_val': 2.6030335426330566,
#   'values': [' <= 2925.505', ' > 2925.505'],
#   'pos_nan': [1, 0],
#   'min_split': 3816,
#   'p_value': 10.559278992236514,
#   'sign_split': 99},
#  {'stat_val': 2.838852882385254,
#   'values': [' <= 680.912', ' > 680.912'],
#   'pos_nan': [1, 0],
#   'min_split': 777,
#   'p_value': 9.108977936831169,
#   'sign_split': 99},
#  {'stat_val': 4.278775691986084,
#   'values': [' <= 683.01', ' > 683.01'],
#   'pos_nan': [1, 0],
#   'min_split': 812,
#   'p_value': 3.8205224631934267,
#   'sign_split': 99},
#  {'stat_val': 6.7552618980407715,
#   'values': [' <= 6335.046', ' > 6335.046'],
#   'pos_nan': [1, 0],
#   'min_split': 2541,
#   'p_value': 0.9253690992533696,
#   'sign_split': 99},
#  {'stat_val': 4.924587726593018,
#   'values': [' <= 1252.947', ' > 1252.947'],
#   'pos_nan': [1, 0],
#   'min_split': 1890,
#   'p_value': 2.6212347744906124,
#   'sign_split': 99},
#  {'stat_val': 3.714319944381714,
#   'values': [' <= 7272.884', ' > 7272.884'],
#   'pos_nan': [1, 0],
#   'min_split': 1179,
#   'p_value': 5.340812065094496,
#   'sign_split': 99},
#  {'stat_val': 12.159540176391602,
#   'values': [' <= 7820.959', ' > 7820.959'],
#   'pos_nan': [1, 0],
#   'min_split': 272,
#   'p_value': 0.04834904161861657,
#   'sign_split': 99},
#  {'stat_val': 7.225264549255371,
#   'values': [' <= 2685.098', ' > 2685.098'],
#   'pos_nan': [1, 0],
#   'min_split': 4512,
#   'p_value': 0.7116573232537915,
#   'sign_split': 99},
#  {'stat_val': 2.0737671852111816,
#   'values': [' <= 2152.894', ' > 2152.894'],
#   'pos_nan': [1, 0],
#   'min_split': 3796,
#   'p_value': 14.835246670049097,
#   'sign_split': 99},
#  {'stat_val': 4.551609992980957,
#   'values': [' <= 440.577', ' > 440.577'],
#   'pos_nan': [1, 0],
#   'min_split': 604,
#   'p_value': 3.2558930115707674,
#   'sign_split': 99},
#  {'stat_val': 3.723994731903076,
#   'values': [' <= 7836.956', ' > 7836.956'],
#   'pos_nan': [1, 0],
#   'min_split': 312,
#   'p_value': 5.30995458846055,
#   'sign_split': 99},
#  {'stat_val': 4.185775279998779,
#   'values': [' <= 7918.431', ' > 7918.431'],
#   'pos_nan': [1, 0],
#   'min_split': 161,
#   'p_value': 4.035691806372364,
#   'sign_split': 99},
#  {'stat_val': 4.545165538787842,
#   'values': [' <= 7765.437', ' > 7765.437'],
#   'pos_nan': [1, 0],
#   'min_split': 498,
#   'p_value': 3.268171166348116,
#   'sign_split': 99},
#  {'stat_val': 3.1436712741851807,
#   'values': [' <= 7424.028', ' > 7424.028'],
#   'pos_nan': [1, 0],
#   'min_split': 1197,
#   'p_value': 7.545983816998861,
#   'sign_split': 99},
#  {'stat_val': 6.167334079742432,
#   'values': [' <= 2616.805', ' > 2616.805'],
#   'pos_nan': [1, 0],
#   'min_split': 5632,
#   'p_value': 1.2882925650653343,
#   'sign_split': 99},
#  {'stat_val': 3.471365451812744,
#   'values': [' <= 1332.304', ' > 1332.304'],
#   'pos_nan': [1, 0],
#   'min_split': 2715,
#   'p_value': 6.181535118687418,
#   'sign_split': 99},
#  {'stat_val': 7.939157009124756,
#   'values': [' <= 7429.218', ' > 7429.218'],
#   'pos_nan': [1, 0],
#   'min_split': 1302,
#   'p_value': 0.47892601755750125,
#   'sign_split': 99},
#  {'stat_val': 4.51392126083374,
#   'values': [' <= 3357.462', ' > 3357.462'],
#   'pos_nan': [1, 0],
#   'min_split': 7831,
#   'p_value': 3.328387970181657,
#   'sign_split': 99},
#  {'stat_val': 4.359832286834717,
#   'values': [' <= 7462.586', ' > 7462.586'],
#   'pos_nan': [1, 0],
#   'min_split': 1372,
#   'p_value': 3.6427968377926065,
#   'sign_split': 99}]

# %%
res_old
# Out:
# [{'stat_val': 1.9248254299163818,
#   'values': [' >= 6508.95', ' < 6508.95'],
#   'pos_nan': [1, 0],
#   'min_split': 22,
#   'p_value': 13.060728912897732,
#   'sign_split': 79},
#  {'stat_val': 4.240798473358154,
#   'values': [' >= 7730.186', ' < 7730.186'],
#   'pos_nan': [1, 0],
#   'min_split': 24,
#   'p_value': 3.827969474595702,
#   'sign_split': 97},
#  {'stat_val': 3.306309223175049,
#   'values': [' >= 7841.65', ' < 7841.65'],
#   'pos_nan': [1, 0],
#   'min_split': 22,
#   'p_value': 6.832418708801845,
#   'sign_split': 99},
#  {'stat_val': 9.291913032531738,
#   'values': [' >= 3560.759', ' < 3560.759'],
#   'pos_nan': [1, 0],
#   'min_split': 688,
#   'p_value': 0.22786599415610534,
#   'sign_split': 99},
#  {'stat_val': 4.049301624298096,
#   'values': [' >= 255.019', ' < 255.019'],
#   'pos_nan': [1, 0],
#   'min_split': 42,
#   'p_value': 4.374772631387701,
#   'sign_split': 99},
#  {'stat_val': 2.5701167583465576,
#   'values': [' >= 6839.233', ' < 6839.233'],
#   'pos_nan': [1, 0],
#   'min_split': 390,
#   'p_value': 10.78106969844296,
#   'sign_split': 99},
#  {'stat_val': 4.834317684173584,
#   'values': [' >= 7178.22', ' < 7178.22'],
#   'pos_nan': [1, 0],
#   'min_split': 310,
#   'p_value': 2.761969177805329,
#   'sign_split': 99},
#  {'stat_val': 6.199769973754883,
#   'values': [' >= 1485.414', ' < 1485.414'],
#   'pos_nan': [1, 0],
#   'min_split': 684,
#   'p_value': 1.2648924747316572,
#   'sign_split': 99},
#  {'stat_val': 4.891524791717529,
#   'values': [' >= 435.581', ' < 435.581'],
#   'pos_nan': [1, 0],
#   'min_split': 164,
#   'p_value': 2.671895172476448,
#   'sign_split': 99},
#  {'stat_val': 3.966035842895508,
#   'values': [' >= 1664.243', ' < 1664.243'],
#   'pos_nan': [1, 0],
#   'min_split': 920,
#   'p_value': 4.596267965447167,
#   'sign_split': 99},
#  {'stat_val': 3.124359369277954,
#   'values': [' >= 4333.113', ' < 4333.113'],
#   'pos_nan': [1, 0],
#   'min_split': 2397,
#   'p_value': 7.635888086376121,
#   'sign_split': 99},
#  {'stat_val': 9.97868824005127,
#   'values': [' >= 6030.012', ' < 6030.012'],
#   'pos_nan': [1, 0],
#   'min_split': 1344,
#   'p_value': 0.15677883836777895,
#   'sign_split': 99},
#  {'stat_val': 9.188007354736328,
#   'values': [' >= 5581.857', ' < 5581.857'],
#   'pos_nan': [1, 0],
#   'min_split': 1891,
#   'p_value': 0.24116988754082086,
#   'sign_split': 99},
#  {'stat_val': 6.763279438018799,
#   'values': [' >= 4161.476', ' < 4161.476'],
#   'pos_nan': [1, 0],
#   'min_split': 3234,
#   'p_value': 0.9212207062295539,
#   'sign_split': 99},
#  {'stat_val': 3.321990728378296,
#   'values': [' >= 7341.855', ' < 7341.855'],
#   'pos_nan': [1, 0],
#   'min_split': 568,
#   'p_value': 6.767541748676621,
#   'sign_split': 99},
#  {'stat_val': 7.546189308166504,
#   'values': [' >= 701.489', ' < 701.489'],
#   'pos_nan': [1, 0],
#   'min_split': 532,
#   'p_value': 0.5953574535709721,
#   'sign_split': 99},
#  {'stat_val': 5.039513111114502,
#   'values': [' >= 7925.371', ' < 7925.371'],
#   'pos_nan': [1, 0],
#   'min_split': 81,
#   'p_value': 2.4527697995489794,
#   'sign_split': 99},
#  {'stat_val': 4.7320756912231445,
#   'values': [' >= 4807.366', ' < 4807.366'],
#   'pos_nan': [1, 0],
#   'min_split': 3526,
#   'p_value': 2.9309084998434844,
#   'sign_split': 99},
#  {'stat_val': 4.346709251403809,
#   'values': [' >= 2336.364', ' < 2336.364'],
#   'pos_nan': [1, 0],
#   'min_split': 2548,
#   'p_value': 3.670972377589758,
#   'sign_split': 99},
#  {'stat_val': 2.7300808429718018,
#   'values': [' >= 7155.247', ' < 7155.247'],
#   'pos_nan': [1, 0],
#   'min_split': 1056,
#   'p_value': 9.748955709556341,
#   'sign_split': 99},
#  {'stat_val': 1.2770568132400513,
#   'values': [' >= 6506.997', ' < 6506.997'],
#   'pos_nan': [1, 0],
#   'min_split': 1919,
#   'p_value': 25.5862519213238,
#   'sign_split': 99},
#  {'stat_val': 2.6030335426330566,
#   'values': [' >= 2925.505', ' < 2925.505'],
#   'pos_nan': [1, 0],
#   'min_split': 3816,
#   'p_value': 10.559278992236514,
#   'sign_split': 99},
#  {'stat_val': 2.838852882385254,
#   'values': [' >= 680.912', ' < 680.912'],
#   'pos_nan': [1, 0],
#   'min_split': 777,
#   'p_value': 9.108977936831169,
#   'sign_split': 99},
#  {'stat_val': 4.278775691986084,
#   'values': [' >= 683.01', ' < 683.01'],
#   'pos_nan': [1, 0],
#   'min_split': 812,
#   'p_value': 3.8205224631934267,
#   'sign_split': 99},
#  {'stat_val': 6.7552618980407715,
#   'values': [' >= 6335.046', ' < 6335.046'],
#   'pos_nan': [1, 0],
#   'min_split': 2541,
#   'p_value': 0.9253690992533696,
#   'sign_split': 99},
#  {'stat_val': 4.924587726593018,
#   'values': [' >= 1252.947', ' < 1252.947'],
#   'pos_nan': [1, 0],
#   'min_split': 1890,
#   'p_value': 2.6212347744906124,
#   'sign_split': 99},
#  {'stat_val': 3.714319944381714,
#   'values': [' >= 7272.884', ' < 7272.884'],
#   'pos_nan': [1, 0],
#   'min_split': 1179,
#   'p_value': 5.340812065094496,
#   'sign_split': 99},
#  {'stat_val': 12.159540176391602,
#   'values': [' >= 7820.959', ' < 7820.959'],
#   'pos_nan': [1, 0],
#   'min_split': 272,
#   'p_value': 0.04834904161861657,
#   'sign_split': 99},
#  {'stat_val': 7.225264549255371,
#   'values': [' >= 2685.098', ' < 2685.098'],
#   'pos_nan': [1, 0],
#   'min_split': 4512,
#   'p_value': 0.7116573232537915,
#   'sign_split': 99},
#  {'stat_val': 2.0737671852111816,
#   'values': [' >= 2152.894', ' < 2152.894'],
#   'pos_nan': [1, 0],
#   'min_split': 3796,
#   'p_value': 14.835246670049097,
#   'sign_split': 99},
#  {'stat_val': 4.551609992980957,
#   'values': [' >= 440.577', ' < 440.577'],
#   'pos_nan': [1, 0],
#   'min_split': 604,
#   'p_value': 3.2558930115707674,
#   'sign_split': 99},
#  {'stat_val': 3.723994731903076,
#   'values': [' >= 7836.956', ' < 7836.956'],
#   'pos_nan': [1, 0],
#   'min_split': 312,
#   'p_value': 5.30995458846055,
#   'sign_split': 99},
#  {'stat_val': 4.185775279998779,
#   'values': [' >= 7918.431', ' < 7918.431'],
#   'pos_nan': [1, 0],
#   'min_split': 161,
#   'p_value': 4.035691806372364,
#   'sign_split': 99},
#  {'stat_val': 4.545165538787842,
#   'values': [' >= 7765.437', ' < 7765.437'],
#   'pos_nan': [1, 0],
#   'min_split': 498,
#   'p_value': 3.268171166348116,
#   'sign_split': 99},
#  {'stat_val': 3.1436712741851807,
#   'values': [' >= 7424.028', ' < 7424.028'],
#   'pos_nan': [1, 0],
#   'min_split': 1197,
#   'p_value': 7.545983816998861,
#   'sign_split': 99},
#  {'stat_val': 6.167334079742432,
#   'values': [' >= 2616.805', ' < 2616.805'],
#   'pos_nan': [1, 0],
#   'min_split': 5632,
#   'p_value': 1.2882925650653343,
#   'sign_split': 99},
#  {'stat_val': 3.471365451812744,
#   'values': [' >= 1332.304', ' < 1332.304'],
#   'pos_nan': [1, 0],
#   'min_split': 2715,
#   'p_value': 6.181535118687418,
#   'sign_split': 99},
#  {'stat_val': 7.939157009124756,
#   'values': [' >= 7429.218', ' < 7429.218'],
#   'pos_nan': [1, 0],
#   'min_split': 1302,
#   'p_value': 0.47892601755750125,
#   'sign_split': 99},
#  {'stat_val': 4.51392126083374,
#   'values': [' >= 3357.462', ' < 3357.462'],
#   'pos_nan': [1, 0],
#   'min_split': 7831,
#   'p_value': 3.328387970181657,
#   'sign_split': 99},
#  {'stat_val': 4.359832286834717,
#   'values': [' >= 7462.586', ' < 7462.586'],
#   'pos_nan': [1, 0],
#   'min_split': 1372,
#   'p_value': 3.6427968377926065,
#   'sign_split': 99}]

# %%
dur = np.random.uniform(0, 10000, 9600)
cens = np.random.choice(2, 9600)
vals = np.random.uniform(100, 8000, 9600)

arr = np.vstack([vals, cens, dur])

# %%
# %timeit best_attr_split(arr)
# Out:
# 139 ms ± 935 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit half_miss_hist_best_attr_split(arr)
# Out:
# 46 ms ± 338 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit miss_hist_best_attr_split(arr)
# Out:
# 88.2 ms ± 518 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit hist_best_attr_split(arr)
# Out:
# 28.8 ms ± 194 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
profiler = cProfile.Profile()
profiler.enable()
half_miss_hist_best_attr_split(arr)
profiler.disable()
stats_ = pstats.Stats(profiler).sort_stats('cumtime')
stats_.print_stats()
stats_.dump_stats('half_miss.pstats')
# Out:
#          3931 function calls (3905 primitive calls) in 0.051 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.051    0.025 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\IPython\core\interactiveshell.py:3362(run_code)
#         2    0.000    0.000    0.051    0.025 {built-in method builtins.exec}
#         1    0.000    0.000    0.051    0.051 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\1700740042.py:1(<cell line: 3>)
#         1    0.006    0.006    0.051    0.051 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3674147823.py:12(half_miss_hist_best_attr_split)
#        99    0.003    0.000    0.035    0.000 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\2618755487.py:48(optimal_criter_split_hist)
#       198    0.000    0.000    0.032    0.000 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\2618755487.py:45(logrank_hist)
#       198    0.001    0.000    0.031    0.000 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\2618755487.py:28(weight_hist_stat)
#       198    0.027    0.000    0.027    0.000 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\2618755487.py:1(lr_hist_statistic)
#   253/227    0.004    0.000    0.007    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       992    0.005    0.000    0.005    0.000 {method 'astype' of 'numpy.ndarray' objects}
#       202    0.000    0.000    0.004    0.000 <__array_function__ internals>:177(bincount)
#       100    0.000    0.000    0.001    0.000 {method 'sum' of 'numpy.ndarray' objects}
#       110    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       100    0.000    0.000    0.001    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_methods.py:46(_sum)
#         1    0.000    0.000    0.001    0.001 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\2618755487.py:67(split_time_to_bins)
#         5    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(unique)
#         6    0.000    0.000    0.001    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:51(_wrapfunc)
#         5    0.000    0.000    0.001    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\arraysetops.py:138(unique)
#         2    0.000    0.000    0.001    0.001 <__array_function__ internals>:177(searchsorted)
#         2    0.000    0.000    0.001    0.001 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:1319(searchsorted)
#         5    0.000    0.000    0.001    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\arraysetops.py:320(_unique1d)
#         2    0.001    0.001    0.001    0.001 {method 'searchsorted' of 'numpy.ndarray' objects}
#         5    0.001    0.000    0.001    0.000 {method 'sort' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(quantile)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4143(quantile)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4375(_quantile_unchecked)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:3651(_ureduce)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4527(_quantile_ureduce_func)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4595(_quantile)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(digitize)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:5399(digitize)
#         1    0.000    0.000    0.000    0.000 {method 'partition' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_distn_infrastructure.py:2044(sf)
#        99    0.000    0.000    0.000    0.000 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\2618755487.py:71(get_attrs)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_distn_infrastructure.py:529(argsreduce)
#       100    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#       198    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         5    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(append)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(broadcast_arrays)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:479(broadcast_arrays)
#         5    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:69(_wrapreduction)
#         5    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:5337(append)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\codeop.py:117(__call__)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(all)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4396(_quantile_is_valid)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(any)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:545(<listcomp>)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:2404(all)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:339(_broadcast_to)
#         6    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(concatenate)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4560(_get_indexes)
#       200    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_distn_infrastructure.py:998(_open_support_mask)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(zeros_like)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:2305(any)
#         6    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:597(find_common_type)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numeric.py:76(zeros_like)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(round_)
#       202    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\multiarray.py:883(bincount)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:3764(round_)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:573(_can_coerce_all)
#       101    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(around)
#         4    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:356(issubdtype)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:3257(around)
#         5    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(ravel)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(take)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\IPython\core\interactiveshell.py:3215(_update_code_co_name)
#         5    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_methods.py:54(_any)
#         1    0.000    0.000    0.000    0.000 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3674147823.py:30(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'round' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(place)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_ufunc_config.py:32(seterr)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4472(_lerp)
#         2    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.generic' objects}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_ufunc_config.py:429(__enter__)
#        99    0.000    0.000    0.000    0.000 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\3674147823.py:90(<lambda>)
#         1    0.000    0.000    0.000    0.000 {method 'min' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:93(take)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_methods.py:42(_amin)
#         5    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:1755(ravel)
#         8    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:282(issubclass_)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(atleast_1d)
#        31    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#         3    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(copyto)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numeric.py:289(full)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:1888(place)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_methods.py:38(_amax)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_distn_infrastructure.py:959(_argcheck)
#         6    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(empty_like)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\shape_base.py:23(atleast_1d)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\contextlib.py:279(helper)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_continuous_distns.py:1315(_sf)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:415(_broadcast_shape)
#        13    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         5    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\arraysetops.py:125(_unpack_tuple)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4450(_get_gamma)
#         1    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.generic' objects}
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(shape)
#         3    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#        14    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:582(<listcomp>)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\contextlib.py:102(__init__)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\contextlib.py:130(__enter__)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\contextlib.py:139(__exit__)
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_ufunc_config.py:131(geterr)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_ufunc_config.py:434(__exit__)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:110(<lambda>)
#         3    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\IPython\core\compilerop.py:174(extra_flags)
#         5    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:70(<dictcomp>)
#         7    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath._insert}
#         4    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\dis.py:453(findlinestarts)
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_methods.py:60(_all)
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\traitlets\traitlets.py:675(__get__)
#         1    0.000    0.000    0.000    0.000 C:\Users\vasiliev\AppData\Local\Temp\ipykernel_1692\1700740042.py:1(<cell line: 4>)
#         9    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:649(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:537(<listcomp>)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:346(iterable)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_distn_infrastructure.py:573(<listcomp>)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\traitlets\traitlets.py:643(get)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'code' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\_ufunc_config.py:425(__init__)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\IPython\core\interactiveshell.py:3313(compare)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#        25    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         4    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:541(<genexpr>)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\scipy\stats\_distn_infrastructure.py:971(_get_support)
#         5    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#         6    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\multiarray.py:148(concatenate)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\multiarray.py:80(empty_like)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numeric.py:72(_zeros_like_dispatcher)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:25(_maybe_view_as_subclass)
#         5    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:5333(_append_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:2300(_any_dispatcher)
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         5    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:1884(_place_dispatcher)
#         5    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\arraysetops.py:133(_unique_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\IPython\core\interactiveshell.py:1192(user_global_ns)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath._monotonicity}
#         3    0.000    0.000    0.000    0.000 {method '__exit__' of 'numpy.nditer' objects}
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:1965(shape)
#         2    0.000    0.000    0.000    0.000 {method 'co_lines' of 'code' objects}
#         6    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:344(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\numerictypes.py:650(<listcomp>)
#         5    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:1751(_ravel_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:1961(_shape_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:5395(_digitize_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:1315(_searchsorted_dispatcher)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:2399(_all_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:3253(_around_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\stride_tricks.py:475(_broadcast_arrays_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:4138(_quantile_dispatcher)
#         1    0.000    0.000    0.000    0.000 <string>:2(_parse_args)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\shape_base.py:19(_atleast_1d_dispatcher)
#         3    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\fromnumeric.py:89(_take_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\lib\function_base.py:111(<lambda>)
#         4    0.000    0.000    0.000    0.000 C:\ProgramData\Anaconda3\envs\survive\lib\site-packages\numpy\core\multiarray.py:1071(copyto)

# %%
np.bincount(np.array([1, 2, 3]),
            weights = np.array([[1, 0, 1], [0, 1, 1]]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [261], in <cell line: 1>()
# ----> 1 np.bincount(np.array([1, 2, 3]),
#       2             weights = np.array([[1, 0, 1], [0, 1, 1]]))
#
# File <__array_function__ internals>:180, in bincount(*args, **kwargs)
#
# ValueError: object too deep for desired array
